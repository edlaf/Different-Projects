# %%
import AutoEncoder as AutoEncoder
import AutoEncoder_models as AutoEncoder_models
import torch
import torch.nn as nn

# %%
path = "/Users/edouard/Desktop/Projets perso/Deep Learning/Datasets/celeba_hq_256"
device = "cpu" #torch.device("" if torch.cuda.is_available else "cpu")

train, test = AutoEncoder.load_data(path)

images, _ = next(iter(train))

AutoEncoder.show(images)

# %%
model = AutoEncoder_models.Auto_Encoder(latent_channels=2).to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
AutoEncoder.train(model, criterion, train, optimizer, test,  device)
# Out:
# Number of parameters of the model 273733
# Epoch 1/10:   0%|          | 0/211 [00:05<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 AutoEncoder.train(model, criterion, train, optimizer, test,  device)
#
# File ~/Desktop/Projets perso/Deep Learning/Models/Latent Diffusion Model /AutoEncoder.py:83, in train(model, criterion, trainloader, optimizer, testloader, device, nb_epochs, display_interval)
#      81 for images, _ in progress_bar:
#      82     images = images.to(device)
# ---> 83     reconstructed_images = model(images)
#      85     loss = criterion(reconstructed_images, images)
#      86     optimizer.zero_grad()
#
# File ~/miniforge3/envs/IA_m1/lib/python3.9/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
# ...

# %%
AutoEncoder.test(model, criterion, test, device)
